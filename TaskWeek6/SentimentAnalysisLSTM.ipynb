# %% [markdown]
# <a href="https://colab.research.google.com/github/keziammanuela/KomputasiIntelegensiaTasks/blob/main/TaskWeek6/SentimentAnalysisLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Sentiment Analysis with LSTM**

# %% [markdown]
# Nama: Kezia Emmanuela Bangun
#
# NPM: 2006572964
#
# Original Code: https://www.kaggle.com/code/yossefmohammed/twitter-sentiment-analysis-with-lstm

# %%
import pandas as pd
import os
import re
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download required NLTK data in default path for Colab
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')

# Specify nltk data path to ensure compatibility
nltk.data.path.append("/content/nltk_data/")

# Example usage of NLTK libraries
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %% [markdown]
# # Import the data from Kaggle

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
jp797498e_twitter_entity_sentiment_analysis_path = kagglehub.dataset_download('jp797498e/twitter-entity-sentiment-analysis')

print('Data source import complete.')
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.3)
# Downloading from https://www.kaggle.com/api/v1/datasets/download/jp797498e/twitter-entity-sentiment-analysis?dataset_version_number=2...
# 100%|██████████| 1.99M/1.99M [00:00<00:00, 44.4MB/s]
# Extracting files...
# Data source import complete.

# %%
# Get the path to the downloaded dataset
dataset_path = jp797498e_twitter_entity_sentiment_analysis_path

# Check the files available in the dataset path
print(os.listdir(dataset_path))
# Out:
# ['twitter_validation.csv', 'twitter_training.csv']

# %% [markdown]
# # Load the training and testing data

# %%
# Load the CSV files using the correct path
training = pd.read_csv(os.path.join(dataset_path, "twitter_training.csv"))
test = pd.read_csv(os.path.join(dataset_path, "twitter_validation.csv"))

# %%
training.head()
# Out:
#    2401  Borderlands  Positive  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#   im getting on borderlands and i will murder you all ,
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
test.head()
# Out:
#    3364   Facebook Irrelevant  \
# 0   352     Amazon    Neutral
# 1  8312  Microsoft   Negative
# 2  4371      CS-GO   Negative
# 3  4433     Google    Neutral
# 4  6273       FIFA   Negative
#
#   I mentioned on Facebook that I was struggling for motivation to go for a run the other day, which has been translated by Tom’s great auntie as ‘Hayley can’t get out of bed’ and told to his grandma, who now thinks I’m a lazy, terrible person 🤣
# 0  BBC News - Amazon boss Jeff Bezos rejects clai...
# 1  @Microsoft Why do I pay for WORD when it funct...
# 2  CSGO matchmaking is so full of closet hacking,...
# 3  Now the President is slapping Americans in the...
# 4  Hi @EAHelp I’ve had Madeleine McCann in my cel...

# %% [markdown]
# # Add headers for the columns in each dataframe:

# %%
test.columns = ['Header1', 'company','labels','text']
training.columns = ['Header1', 'company','labels','text']

# %%
print(training)
print("---------------------------------------------------------------------")
print(test)
# Out:
#        Header1      company    labels  \
# 0         2401  Borderlands  Positive
# 1         2401  Borderlands  Positive
# 2         2401  Borderlands  Positive
# 3         2401  Borderlands  Positive
# 4         2401  Borderlands  Positive
# ...        ...          ...       ...
# 74676     9200       Nvidia  Positive
# 74677     9200       Nvidia  Positive
# 74678     9200       Nvidia  Positive
# 74679     9200       Nvidia  Positive
# 74680     9200       Nvidia  Positive
#
#                                                     text
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 74676  Just realized that the Windows partition of my...
# 74677  Just realized that my Mac window partition is ...
# 74678  Just realized the windows partition of my Mac ...
# 74679  Just realized between the windows partition of...
# 74680  Just like the windows partition of my Mac is l...
#
# [74681 rows x 4 columns]
# ---------------------------------------------------------------------
#      Header1              company      labels  \
# 0        352               Amazon     Neutral
# 1       8312            Microsoft    Negative
# 2       4371                CS-GO    Negative
# 3       4433               Google     Neutral
# 4       6273                 FIFA    Negative
# ..       ...                  ...         ...
# 994     4891  GrandTheftAuto(GTA)  Irrelevant
# 995     4359                CS-GO  Irrelevant
# 996     2652          Borderlands    Positive
# 997     8069            Microsoft    Positive
# 998     6960      johnson&johnson     Neutral
#
#                                                   text
# 0    BBC News - Amazon boss Jeff Bezos rejects clai...
# 1    @Microsoft Why do I pay for WORD when it funct...
# 2    CSGO matchmaking is so full of closet hacking,...
# 3    Now the President is slapping Americans in the...
# 4    Hi @EAHelp I’ve had Madeleine McCann in my cel...
# ..                                                 ...
# 994  ⭐️ Toronto is the arts and culture capital of ...
# 995  tHIS IS ACTUALLY A GOOD MOVE TOT BRING MORE VI...
# 996  Today sucked so it’s time to drink wine n play...
# 997  Bought a fraction of Microsoft today. Small wins.
# 998  Johnson & Johnson to stop selling talc baby po...
#
# [999 rows x 4 columns]

# %% [markdown]
# # Delete unneeded columns

# %%
training.drop(columns=["Header1","company"],inplace=True)
test.drop(columns=["Header1","company"],inplace=True)

# %%
training.head()
# Out:
#      labels                                               text
# 0  Positive  I am coming to the borders and I will kill you...
# 1  Positive  im getting on borderlands and i will kill you ...
# 2  Positive  im coming on borderlands and i will murder you...
# 3  Positive  im getting on borderlands 2 and i will murder ...
# 4  Positive  im getting into borderlands and i can murder y...

# %%
test.head()
# Out:
#      labels                                               text
# 0   Neutral  BBC News - Amazon boss Jeff Bezos rejects clai...
# 1  Negative  @Microsoft Why do I pay for WORD when it funct...
# 2  Negative  CSGO matchmaking is so full of closet hacking,...
# 3   Neutral  Now the President is slapping Americans in the...
# 4  Negative  Hi @EAHelp I’ve had Madeleine McCann in my cel...

# %% [markdown]
# # Add the two data frame in one datarame

# %%
sentiment=pd.concat([training,test],ignore_index=True)
sentiment
# Out:
#            labels                                               text
# 0        Positive  I am coming to the borders and I will kill you...
# 1        Positive  im getting on borderlands and i will kill you ...
# 2        Positive  im coming on borderlands and i will murder you...
# 3        Positive  im getting on borderlands 2 and i will murder ...
# 4        Positive  im getting into borderlands and i can murder y...
# ...           ...                                                ...
# 75675  Irrelevant  ⭐️ Toronto is the arts and culture capital of ...
# 75676  Irrelevant  tHIS IS ACTUALLY A GOOD MOVE TOT BRING MORE VI...
# 75677    Positive  Today sucked so it’s time to drink wine n play...
# 75678    Positive  Bought a fraction of Microsoft today. Small wins.
# 75679     Neutral  Johnson & Johnson to stop selling talc baby po...
#
# [75680 rows x 2 columns]

# %% [markdown]
# # EDA/Check for cleaning data

# %%
sentiment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75680 entries, 0 to 75679
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   labels  75680 non-null  object
#  1   text    74994 non-null  object
# dtypes: object(2)
# memory usage: 1.2+ MB

# %%
sentiment.isnull().sum()
# Out:
# labels      0
# text      686
# dtype: int64

# %%
sentiment.dropna(inplace=True)
sentiment.isnull().sum()
# Out:
# labels    0
# text      0
# dtype: int64

# %%
sentiment.duplicated().sum()
# Out:
# 4743

# %%
sentiment.drop_duplicates(inplace=True)
sentiment.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Preprocessing the text n the data:

# %% [markdown]
# # This function for cleaning the text:

# %%
def process_text(text):
    text = re.sub(r'\s+', ' ', text, flags=re.I) # Remove extra white space from text

    text = re.sub(r'\W', ' ', str(text)) # Remove all the special characters from text

    text = re.sub(r'\s+[a-zA-Z]\s+', ' ', text) # Remove all single characters from text

    text = re.sub(r'[^a-zA-Z\s]', '', text) # Remove any character that isn't alphabetical

    text = text.lower()

    words = word_tokenize(text)

    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]

    stop_words = set(stopwords.words("english"))
    Words = [word for word in words if word not in stop_words]

    Words = [word for word in Words if len(word) > 3]

    indices = np.unique(Words, return_index=True)[1]
    cleaned_text = np.array(Words)[np.sort(indices)].tolist()

    return cleaned_text

# %%
x=sentiment.drop('labels',axis=1)
y=sentiment.labels

# %%
texts=list(x['text'])

# %%
cleaned_text = [process_text(text) for text in texts]

# %%
print(cleaned_text[:10])
# Out:
# [['coming', 'border', 'kill'], ['getting', 'borderland', 'kill'], ['coming', 'borderland', 'murder'], ['getting', 'borderland', 'murder'], ['getting', 'borderland', 'murder'], ['spent', 'hour', 'making', 'something', 'know', 'huge', 'borderland', 'maya', 'favorite', 'character', 'decided', 'make', 'wallpaper', 'original', 'image', 'versus', 'creation', 'made', 'enjoy', 'twitter', 'mlsiwfjg'], ['spent', 'couple', 'hour', 'something', 'know', 'huge', 'borderland', 'maya', 'favorite', 'character', 'decided', 'make', 'wallpaper', 'original', 'picture', 'compared', 'creation', 'made', 'twitter', 'mlsiwfjg'], ['spent', 'hour', 'something', 'know', 'huge', 'borderland', 'maya', 'favorite', 'character'], ['spent', 'hour', 'making', 'something', 'know', 'huge', 'rhandlerr', 'maya', 'favorite', 'character', 'decided', 'make', 'wallpaper', 'original', 'image', 'versus', 'creation', 'made', 'enjoy', 'twitter', 'mlsiwfjg'], ['spent', 'hour', 'making', 'something', 'know', 'huge', 'rhandlerr', 'maya', 'favorite', 'character', 'decided', 'make', 'wallpaper', 'original', 'image', 'versus', 'creation', 'made', 'enjoy', 'twitter', 'mlsiwfjg']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(cleaned_text, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Prepare the data to the model:

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_vocab = 20000
tokenizer = Tokenizer(num_words=max_vocab)
tokenizer.fit_on_texts(X_train)
word_idx = tokenizer.word_index  # Corrected syntax for accessing word index
v = len(word_idx)
print("the size of vocab =", v)  # Corrected spacing
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)
# Out:
# the size of vocab = 24048

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

maxlen = 100
X_train = pad_sequences(X_train,maxlen=maxlen)
X_test = pad_sequences(X_test,maxlen=maxlen)

# %%
y.value_counts()
# Out:
# labels
# Negative      21329
# Positive      19270
# Neutral       17281
# Irrelevant    12371
# Name: count, dtype: int64

# %% [markdown]
# # Build the model

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense,Input,GlobalMaxPooling1D,Dropout,Bidirectional
from tensorflow.keras.models import Model
from keras import optimizers
import numpy as np
D=100
inputt=Input(shape=(maxlen,))

# %%
from tensorflow.keras.optimizers import Adam
learning_rate = 0.0001  # Set your desired learning rate here
x=Embedding(v+1,D)(inputt)
x = Dropout(0.5)(x)
x = Bidirectional(LSTM(150))(x)
x = Dense(32, activation='relu')(x)
x = Dense(4, activation='softmax')(x)

model = Model(inputt, x)

# Define optimizer with specified learning rate
optimizer = Adam(learning_rate=learning_rate)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
import tensorflow as tf

y_train_one_hot = tf.keras.utils.to_categorical(y_train_encoded)
y_test_one_hot = tf.keras.utils.to_categorical(y_test_encoded)
history = model.fit(X_train, y_train_one_hot, epochs=40, validation_data=(X_test, y_test_one_hot))
# Out:
# Epoch 1/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 32s 15ms/step - accuracy: 0.3606 - loss: 1.3233 - val_accuracy: 0.5764 - val_loss: 1.0293
# Epoch 2/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 38s 15ms/step - accuracy: 0.6095 - loss: 0.9598 - val_accuracy: 0.6804 - val_loss: 0.8196
# Epoch 3/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 40s 15ms/step - accuracy: 0.7150 - loss: 0.7416 - val_accuracy: 0.7278 - val_loss: 0.7006
# Epoch 4/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.7793 - loss: 0.5895 - val_accuracy: 0.7747 - val_loss: 0.6034
# Epoch 5/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8159 - loss: 0.4932 - val_accuracy: 0.8053 - val_loss: 0.5242
# Epoch 6/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8399 - loss: 0.4296 - val_accuracy: 0.8190 - val_loss: 0.4886
# Epoch 7/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8566 - loss: 0.3863 - val_accuracy: 0.8233 - val_loss: 0.4847
# Epoch 8/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8670 - loss: 0.3564 - val_accuracy: 0.8372 - val_loss: 0.4346
# Epoch 9/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8792 - loss: 0.3224 - val_accuracy: 0.8470 - val_loss: 0.4136
# Epoch 10/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 26s 15ms/step - accuracy: 0.8865 - loss: 0.3048 - val_accuracy: 0.8506 - val_loss: 0.4067
# Epoch 11/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8925 - loss: 0.2924 - val_accuracy: 0.8538 - val_loss: 0.3928
# Epoch 12/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8964 - loss: 0.2770 - val_accuracy: 0.8567 - val_loss: 0.3929
# Epoch 13/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9009 - loss: 0.2596 - val_accuracy: 0.8607 - val_loss: 0.3896
# Epoch 14/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9062 - loss: 0.2450 - val_accuracy: 0.8643 - val_loss: 0.3767
# Epoch 15/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9102 - loss: 0.2345 - val_accuracy: 0.8666 - val_loss: 0.3851
# Epoch 16/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9120 - loss: 0.2246 - val_accuracy: 0.8685 - val_loss: 0.3744
# Epoch 17/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9173 - loss: 0.2134 - val_accuracy: 0.8718 - val_loss: 0.3680
# Epoch 18/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 26s 15ms/step - accuracy: 0.9197 - loss: 0.2075 - val_accuracy: 0.8702 - val_loss: 0.3732
# Epoch 19/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 26s 15ms/step - accuracy: 0.9225 - loss: 0.2010 - val_accuracy: 0.8737 - val_loss: 0.3641
# Epoch 20/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9276 - loss: 0.1903 - val_accuracy: 0.8736 - val_loss: 0.3654
# Epoch 21/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9294 - loss: 0.1878 - val_accuracy: 0.8755 - val_loss: 0.3712
# Epoch 22/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9299 - loss: 0.1818 - val_accuracy: 0.8782 - val_loss: 0.3706
# Epoch 23/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 26s 15ms/step - accuracy: 0.9322 - loss: 0.1807 - val_accuracy: 0.8774 - val_loss: 0.3722
# Epoch 24/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9334 - loss: 0.1743 - val_accuracy: 0.8757 - val_loss: 0.3706
# Epoch 25/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9338 - loss: 0.1706 - val_accuracy: 0.8782 - val_loss: 0.3706
# Epoch 26/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9358 - loss: 0.1677 - val_accuracy: 0.8796 - val_loss: 0.3722
# Epoch 27/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 26s 15ms/step - accuracy: 0.9369 - loss: 0.1635 - val_accuracy: 0.8811 - val_loss: 0.3833
# Epoch 28/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9387 - loss: 0.1568 - val_accuracy: 0.8806 - val_loss: 0.3739
# Epoch 29/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.9435 - loss: 0.1484 - val_accuracy: 0.8806 - val_loss: 0.3701
# Epoch 30/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 26s 15ms/step - accuracy: 0.9406 - loss: 0.1541 - val_accuracy: 0.8816 - val_loss: 0.3763
# Epoch 31/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 42s 16ms/step - accuracy: 0.9428 - loss: 0.1477 - val_accuracy: 0.8807 - val_loss: 0.3805
# Epoch 32/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 26s 15ms/step - accuracy: 0.9415 - loss: 0.1507 - val_accuracy: 0.8829 - val_loss: 0.3866
# Epoch 33/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9438 - loss: 0.1440 - val_accuracy: 0.8817 - val_loss: 0.3881
# Epoch 34/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9473 - loss: 0.1356 - val_accuracy: 0.8829 - val_loss: 0.3844
# Epoch 35/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9467 - loss: 0.1378 - val_accuracy: 0.8855 - val_loss: 0.3989
# Epoch 36/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9469 - loss: 0.1371 - val_accuracy: 0.8825 - val_loss: 0.3962
# Epoch 37/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 42s 16ms/step - accuracy: 0.9478 - loss: 0.1333 - val_accuracy: 0.8846 - val_loss: 0.3887
# Epoch 38/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 40s 15ms/step - accuracy: 0.9480 - loss: 0.1341 - val_accuracy: 0.8835 - val_loss: 0.3931
# Epoch 39/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9479 - loss: 0.1327 - val_accuracy: 0.8843 - val_loss: 0.4028
# Epoch 40/40
# 1757/1757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9487 - loss: 0.1298 - val_accuracy: 0.8833 - val_loss: 0.4096

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test_one_hot)

print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8841 - loss: 0.4060
# Test Loss: 0.4095911681652069
# Test Accuracy: 0.8832823038101196

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np


y_pred_probs = model.predict(X_test)
y_pred_labels = np.argmax(y_pred_probs, axis=1)
y_true_labels = np.argmax(y_test_one_hot, axis=1)
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Class 0', 'Class 1', 'Class 2', 'Class 3'],
            yticklabels=['Class 0', 'Class 1', 'Class 2', 'Class 3'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
